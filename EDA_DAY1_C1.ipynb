# %%
import pandas as pd
import numpy as np
import missingno as msnp
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading the Dataset**

# %%
df = pd.read_csv(r'/content/IPL Matches 2008-2020.csv')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# id                          int64
# city                       object
# date               datetime64[ns]
# player_of_match            object
# venue                      object
# neutral_venue               int64
# team1                      object
# team2                      object
# toss_winner                object
# toss_decision              object
# winner                     object
# result                     object
# result_margin             float64
# eliminator                 object
# method                     object
# umpire1                    object
# umpire2                    object
# dtype: object

# %%
df.head(10)
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
# 3  335985      Mumbai 2008-04-20      MV Boucher
# 4  335986     Kolkata 2008-04-20       DJ Hussey
# 5  335987      Jaipur 2008-04-21       SR Watson
# 6  335988   Hyderabad 2008-04-22        V Sehwag
# 7  335989     Chennai 2008-04-23       ML Hayden
# 8  335990   Hyderabad 2008-04-24       YK Pathan
# 9  335991  Chandigarh 2008-04-25   KC Sangakkara
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# ...

# %%
df['venue'].value_counts().plot(kind = 'barh', xlabel = 'Matches Played', ylabel = 'Stadiums')
# Out:
# <Axes: xlabel='Matches Played', ylabel='Stadiums'>

# %%
df['result_margin'].value_counts()
# Out:
# 6.0      95
# 7.0      94
# 5.0      85
# 8.0      67
# 4.0      53
#          ..
# 42.0      1
# 47.0      1
# 87.0      1
# 130.0     1
# 69.0      1
# Name: result_margin, Length: 91, dtype: int64

# %%
df['winner'].value_counts().plot(kind = 'barh', xlabel = 'Times Won', ylabel = 'Teams')
# Out:
# <Axes: xlabel='Times Won', ylabel='Teams'>

# %%
df['eliminator'].value_counts()
# Out:
# N    799
# Y     13
# Name: eliminator, dtype: int64

# %%
df.head()
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
# 3  335985      Mumbai 2008-04-20      MV Boucher
# 4  335986     Kolkata 2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df['result'].value_counts().plot(kind = 'bar', xlabel = 'Match Ended', ylabel = 'Times')
# Out:
# <Axes: xlabel='Match Ended', ylabel='Times'>

# %%
df['toss_decision'].value_counts()
# Out:
# field    496
# bat      320
# Name: toss_decision, dtype: int64

# %%
df['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
df['condition'] = df['date'] > pd.to_datetime('2020-03-09')
df.loc[df['condition'] == True]
# Out:
#           id       city       date player_of_match  \
# 756  1216492  Abu Dhabi 2020-09-19       AT Rayudu
# 757  1216493      Dubai 2020-09-20      MP Stoinis
# 758  1216494  Abu Dhabi 2020-10-21  Mohammed Siraj
# 759  1216495    Sharjah 2020-11-03        S Nadeem
# 760  1216496    Sharjah 2020-09-22       SV Samson
# 761  1216497  Abu Dhabi 2020-10-24        CV Varun
# 762  1216498      Dubai 2020-10-24       CJ Jordan
# 763  1216499  Abu Dhabi 2020-10-28        SA Yadav
# 764  1216500    Sharjah 2020-10-09        R Ashwin
# 765  1216501  Abu Dhabi 2020-10-07     RA Tripathi
# 766  1216502    Sharjah 2020-10-31  Sandeep Sharma
# 767  1216503  Abu Dhabi 2020-10-01      KA Pollard
# 768  1216504      Dubai 2020-09-30     Shivam Mavi
# 769  1216505  Abu Dhabi 2020-11-02        A Nortje
# 770  1216506  Abu Dhabi 2020-11-01      RD Gaikwad
# 771  1216507      Dubai 2020-10-11       R Tewatia
# 772  1216508  Abu Dhabi 2020-09-23       RG Sharma
# ...

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['toss_decision'] == 'field'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811     True
# 812     True
# 813     True
# 814    False
# 815    False
# Name: toss_decision, Length: 816, dtype: bool

# %%
df['toss_decision'] == 'bat'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 811    False
# 812    False
# 813    False
# 814     True
# 815     True
# Name: toss_decision, Length: 816, dtype: bool

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df = df.drop('toss_analysis', axis = 1)

# %%
df
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df['bat'] = df['toss_decision'].apply(lambda x: 1 if x == 'bat' else 0)
df['field'] = df['toss_decision'].apply(lambda x: 1 if x == 'bowl' else 0)
df = df.loc[df['winner'] == 'Mumbai Indians']
df[['bat', 'field']].value_counts().plot(kind = 'bar')
# Out:
# <ipython-input-80-e4372b825cdd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bat'] = df['toss_decision'].apply(lambda x: 1 if x == 'bat' else 0)
# <ipython-input-80-e4372b825cdd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['field'] = df['toss_decision'].apply(lambda x: 1 if x == 'bowl' else 0)
# <Axes: xlabel='bat,field'>
