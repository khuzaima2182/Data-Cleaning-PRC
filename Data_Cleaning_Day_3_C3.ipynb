# %%
import pandas as pd
import missingno as msnp
import re

# %%
df = pd.read_csv(r'/content/MinimumWageData.csv', encoding='ISO-8859-1')

# %%
df.tail()
# Out:
#       Year          State  State.Minimum.Wage  \
# 2857  2020       Virginia                7.25
# 2858  2020     Washington               13.50
# 2859  2020  West Virginia                8.75
# 2860  2020      Wisconsin                7.25
# 2861  2020        Wyoming                5.15
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 2857                             7.25                  7.25
# 2858                            13.50                  7.25
# 2859                             8.75                  7.25
# 2860                             7.25                  7.25
# 2861                             5.15                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 2857                               7.25                    7.25
# 2858                               7.25                   13.50
# 2859                               7.25                    8.75
# ...

# %% [markdown]
# **Renaming the Dataset columns name**

# %%
df = df.set_axis(['Year', 'State', 'State_Minimum_Wage','State_Minimum_Wage_2020($)' ,'Federal_Minimum_Wage', 'Federal_Minimum_Wage_2020($)', 'Effective_Minimum_Wage' ,'Effective_Minimum_Wage_2020($)' ,'CPI_Avg' , 'Department_Of_Labor' ,'Department_Of_Labor_low_val' ,'Department_Of_Labor_low_val_2020($)' , 'Department_Of_Labor_high_val' ,'Department_Of_Labor_high_val_2020($)' ,'FootNote' ] ,axis = 1)

# %%
df
# Out:
#       Year          State  State_Minimum_Wage  State_Minimum_Wage_2020($)  \
# 0     1968        Alabama             0.00000                        0.00
# 1     1968         Alaska             2.10000                       15.61
# 2     1968        Arizona             0.46800                        3.48
# 3     1968       Arkansas             0.15625                        1.16
# 4     1968     California             1.65000                       12.26
# ...    ...            ...                 ...                         ...
# 2857  2020       Virginia             7.25000                        7.25
# 2858  2020     Washington            13.50000                       13.50
# 2859  2020  West Virginia             8.75000                        8.75
# 2860  2020      Wisconsin             7.25000                        7.25
# 2861  2020        Wyoming             5.15000                        5.15
#
#       Federal_Minimum_Wage  Federal_Minimum_Wage_2020($)  \
# ...

# %%
del df['FootNote']

# %%
df
# Out:
#       Year          State  State_Minimum_Wage  State_Minimum_Wage_2020($)  \
# 0     1968        Alabama             0.00000                        0.00
# 1     1968         Alaska             2.10000                       15.61
# 2     1968        Arizona             0.46800                        3.48
# 3     1968       Arkansas             0.15625                        1.16
# 4     1968     California             1.65000                       12.26
# ...    ...            ...                 ...                         ...
# 2857  2020       Virginia             7.25000                        7.25
# 2858  2020     Washington            13.50000                       13.50
# 2859  2020  West Virginia             8.75000                        8.75
# 2860  2020      Wisconsin             7.25000                        7.25
# 2861  2020        Wyoming             5.15000                        5.15
#
#       Federal_Minimum_Wage  Federal_Minimum_Wage_2020($)  \
# ...

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2862 entries, 0 to 2861
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Year                                  2862 non-null   int64
#  1   State                                 2862 non-null   object
#  2   State_Minimum_Wage                    2862 non-null   float64
#  3   State_Minimum_Wage_2020($)            2862 non-null   float64
#  4   Federal_Minimum_Wage                  2862 non-null   float64
#  5   Federal_Minimum_Wage_2020($)          2862 non-null   float64
#  6   Effective_Minimum_Wage                2862 non-null   float64
#  7   Effective_Minimum_Wage_2020($)        2862 non-null   float64
#  8   CPI_Avg                               2862 non-null   float64
#  9   Department_Of_Labor                   2862 non-null   object
# ...

# %%
df.describe()
# Out:
#               Year  State_Minimum_Wage  State_Minimum_Wage_2020($)  \
# count  2862.000000         2862.000000                 2862.000000
# mean   1994.000000            3.754499                    6.441635
# std      15.299732            2.804826                    3.203165
# min    1968.000000            0.000000                    0.000000
# 25%    1981.000000            1.600000                    5.352500
# 50%    1994.000000            3.350000                    7.400000
# 75%    2007.000000            5.150000                    8.450000
# max    2020.000000           14.000000                   15.610000
#
#        Federal_Minimum_Wage  Federal_Minimum_Wage_2020($)  \
# count           2862.000000                   2862.000000
# mean               4.355660                      7.991887
# std                1.959252                      0.895547
# min                1.150000                      6.420000
# 25%                3.350000                      7.340000
# ...

# %% [markdown]
# **Removing Special Characters**

# %%
df['Department_Of_Labor'] = df['Department_Of_Labor'].replace(special_characters,'')

# %%
df['Department_Of_Labor']
# Out:
# 0         ...
# 1         2.1
# 2       26.40
# 3        1.25
# 4        1.65
#         ...
# 2857     7.25
# 2858     13.5
# 2859     8.75
# 2860     7.25
# 2861     5.15
# Name: Department_Of_Labor, Length: 2862, dtype: object

# %%
df.to_csv('updated_wage.csv')
